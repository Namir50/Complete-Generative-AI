# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Bag of words

# %%
df = pd.DataFrame({"text":['people wath ds',
                           'ds watch ds',
                           'people write comment',
                           'ds write comment'],"output":[1,1,0,0]})

# %%
df
# Out:
#                    text  output
# 0        people wath ds       1
# 1           ds watch ds       1
# 2  people write comment       0
# 3      ds write comment       0

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
